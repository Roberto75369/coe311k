# %% [markdown]
# Hello World!

# %%
print("hello")
# Out:
# hello

# %%
name="charlie"
NAME="rob"
print(name)
# Out:
# charlie

# %%
b=true
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-64b9b1e444d5> in <module>
# ----> 1 b=true
#       2 print(b)
#
# NameError: name 'true' is not defined

# %%
num3="pop"
print(num3)
# Out:
# 4

# %%
numin=input("enter a number:")
# Out:
# enter a number:5

# %%
myfile=open("test.dat",'w')
myfile.write(num3)
myfile.write
myfile.write("Hello World")

myfile.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-31a9f0ed02b6> in <module>
#       1 myfile=open("test.dat",'w')
# ----> 2 myfile.write(num3)
#       3 myfile.write("Hello World")
#       4 myfile.close()
#
# TypeError: write() argument must be str, not int

# %%
a=2
b=3
print(a>b)
print(a<b or a==b)
# Out:
# False
# True

# %%
if(a<b):
    print("a<b")
# Out:
# a>b

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,2*np.pi,50)
plt.plot(x,np.sin(x),2*np.pi)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import random


def samplepie(b):

    counter=0
    for i in range(0,b):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        if(x**2+y**2<1):
            counter=counter+1
    return 4*counter/b
a=samplepie(5000)
print(a)
# Out:
# 3.1688

# %% [markdown]
# #  hello world this is my coding work
#
#  print

# %%
import numpy as np 
x=np.pi
print(x)
# Out:
# 3.141592653589793

# %% [markdown]
# ## this is the next step!

# %%
import numpy as np
x=np.pi
print(x)
# Out:
# 3.141592653589793

# %% [markdown]
# # now were going into matplot101

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,2*np.pi,50)

plt.subplot(2, 1, 1) # (row, column, active area)
plt.plot(x, np.sin(x), 'r')
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x), 'g')
plt.subplot(2,1,3)
plt.plot(x,np.tan(x),'b')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-6c6a267f35b4> in <module>
#       8 plt.subplot(2, 1, 2)
#       9 plt.plot(x, np.cos(x), 'g')
# ---> 10 plt.subplot(2,1,3)
#      11 plt.plot(x,np.tan(x),'b')
#      12 plt.show()
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1067
#    1068     fig = gcf()
# -> 1069     a = fig.add_subplot(*args, **kwargs)
#    1070     bbox = a.bbox
#    1071     byebye = []
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      56             else:
#      57                 if num < 1 or num > rows*cols:
# ---> 58                     raise ValueError(
#      59                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      60                 self._subplotspec = GridSpec(
#
# ValueError: num must be 1 <= num <= 2, not 3

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.sin(x)
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 50)
plt.plot(x, np.sin(x), 'r-x', label='Sin(x)')
plt.plot(x, np.cos(x), 'g-^', label='Cos(x)')
plt.legend() # Display the legend.
plt.xlabel('Rads') # Add a label to the x-axis.
plt.ylabel('Amplitude') # Add a label to the y-axis.
plt.title('Sin and Cos Waves') # Add a graph title.
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

z1 = np.empty([2001,2001])
im = plt.imshow(z1, cmap='hot')
fig = plt.colorbar(im,
orientation='horizontal')
plt.show(fig)

# %%
i = 0
j = 0
t = 1
z = np.empty([2001,2001])
for x in np.arange(-10,10,.01):
    i = i + 1
    j = 0
for y in np.arange(-10,10,.01):
    j = j + 1
    z[i][j] = x*x + y*y

# %%
def f1(x,y):
    x = np.linspace(-10, 10, 2000)
    y = np.linspace(-10, 10, 2000)
    X, Y = np.meshgrid(x, y)
    Z = f1(X, Y)
    return (x*x+y*y)
fig1 = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='hot')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
ax.view_init(45, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-18302558ffc8> in <module>
#       7 fig1 = plt.figure()
#       8 ax = plt.axes(projection='3d')
# ----> 9 ax.contour3D(X, Y, Z, 50, cmap='hot')
#      10 ax.set_xlabel('x')
#      11 ax.set_ylabel('y')
#
# NameError: name 'X' is not defined
