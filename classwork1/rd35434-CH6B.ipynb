# %%
import numpy as np
import math
import time
import matplotlib.pyplot as plt

A = np.array([[1, 2, 3, 0, 0],
              [2, 1, 2, 3, 0],
              [3, 2, 1, 2, 3],
              [0, 3, 2, 1, 2],
              [0, 0, 3, 2, 1]])

b = np.array([14, 22, 33, 26, 22])

tol = 1e-6
max_iterations = 1000

def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

x0 = np.zeros_like(b)

start = time.time()
jacobi_solution, jacobi_iterations = jacobi(A, b, x0, tol, max_iterations)
jacobi_time = time.time() - start
#time code gathered from claud ai
start = time.time()
gs_solution, gs_iterations = gauss_seidel(A, b, x0, tol, max_iterations)
gs_time = time.time() - start

print(f"Jacobi Solution: {jacobi_solution}")
print(f"Jacobi Iterations: {jacobi_iterations}")
print(f"Jacobi Time: {jacobi_time:.6f} seconds")
print()
print(f"Gauss-Seidel Solution: {gs_solution}")
print(f"Gauss-Seidel Iterations: {gs_iterations}")
print(f"Gauss-Seidel Time: {gs_time:.6f} seconds")
#neither converge, so we get useless numbers for both of these proving that the matrix being diagnolly dominant is critical.
# Out:
# Jacobi Solution: [3396993125857097728 6892060737523348480 3013160365829545984
#  6892060737523348480 3396993125857097728]
# Jacobi Iterations: 1000
# Jacobi Time: 0.076516 seconds
#
# Gauss-Seidel Solution: [-3222725436718121984 -6880488481881970688 -5296794635246657536
#  -8477445564595290112 -4048213112488550400]
# Gauss-Seidel Iterations: 1000
# Gauss-Seidel Time: 0.056657 seconds
# <ipython-input-2-4b55cfe50680>:23: RuntimeWarning: overflow encountered in long_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# <ipython-input-2-4b55cfe50680>:36: RuntimeWarning: overflow encountered in long_scalars
#   s1 = sum(A[i][j] * x_new[j] for j in range(i))
# <ipython-input-2-4b55cfe50680>:37: RuntimeWarning: overflow encountered in long_scalars
#   s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
# <ipython-input-2-4b55cfe50680>:38: RuntimeWarning: overflow encountered in long_scalars
#   x_new[i] = (b[i] - s1 - s2) / A[i][i]
