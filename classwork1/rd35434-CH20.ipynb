# %%
import numpy as np 
import matplotlib.pyplot as plt
import math
import time 

def f(t, y):
    return -1000 * y + 3000 - 2000 * np.exp(-t)
 
def exact_solution(t):
    return 3 - 0.998 * np.exp(-1000 * t) - 2.002 * np.exp(-t)
 
# backward euler method
def backward_euler(f, y0, t0, tf, h):
    t_values = np.arange(t0, tf + h, h)
    y_values = np.zeros_like(t_values)
    y_values[0] = y0
 
    for i in range(1, len(t_values)):
        t_next = t_values[i]
        y_prev = y_values[i - 1]
 
        g = lambda y_next: y_next - y_prev - h * f(t_next, y_next)
        y_values[i] = fsolve(g, y_prev)
 
    return t_values, y_values
 
# forward euler 
def forward_euler(f, y0, t0, tf, h):
    t_values = np.arange(t0, tf + h, h)
    y_values = np.zeros_like(t_values)
    y_values[0] = y0
 
    for i in range(1, len(t_values)):
        y_values[i] = y_values[i - 1] + h * f(t_values[i - 1], y_values[i - 1])
 
    return t_values, y_values
 
y0 = 0
t0 = 0
tf = 30
step_sizes = [0.1, 0.01, 0.001]
 
for h in step_sizes:
    t_values, y_values = backward_euler(f, y0, t0, tf, h)
    t_values_fe, y_values_fe = forward_euler(f, y0, t0, tf, h)
    y_exact = exact_solution(t_values)
 
    print(f"h = {h}   max error backward euler = {np.max(np.abs(y_values - y_exact)):.6f}")
 
    plt.figure()
    plt.plot(t_values, y_values, "o-", label="Backward Euler")
    plt.plot(t_values_fe, y_values_fe, "s-", label="Forward Euler")
    plt.plot(t_values, y_exact, linestyle="--", label="analytical solution")
    plt.xlabel("Time (t)")
    plt.ylabel("y(t)")
    plt.title(f"Comparison: Forward vs Backward Euler for Stiff ODE h = {h}")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 44
#      41 step_sizes = [0.1, 0.01, 0.001]
#      43 for h in step_sizes:
# ---> 44     t_values, y_values = backward_euler(f, y0, t0, tf, h)
#      45     t_values_fe, y_values_fe = forward_euler(f, y0, t0, tf, h)
#      46     y_exact = exact_solution(t_values)
#
# Cell In[2], line 23, in backward_euler(f, y0, t0, tf, h)
#      20     y_prev = y_values[i - 1]
#      22     g = lambda y_next: y_next - y_prev - h * f(t_next, y_next)
# ---> 23     y_values[i] = fsolve(g, y_prev)
#      25 return t_values, y_values
#
# NameError: name 'fsolve' is not defined
