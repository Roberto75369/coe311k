# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import time

k = 1.0
x_start = 0
x_end = 10
y_0 = 1.0
v_0 = 0.0
 
h_values = [0.01, 0.02, 0.03, 0.05, 0.1, 0.2, 0.3, 0.5]
 
plt.figure(figsize=(10, 5))
 
for h in h_values:
    x_values = np.arange(x_start, x_end + h, h)
    y_values = np.zeros(len(x_values))
    v_values = np.zeros(len(x_values))
 
    y_values[0] = y_0
    v_values[0] = v_0
 
    for i in range(1, len(x_values)):
        x_n = x_values[i - 1]
        y_n = y_values[i - 1]
        v_n = v_values[i - 1]
 
        y_values[i] = y_n + h * v_n
        v_values[i] = v_n + h * (-k * y_n)
 
    plt.plot(x_values, y_values, label=f"h = {h}")
 
plt.xlabel("x")
plt.ylabel("y and v")
plt.title("Solution of d2y/dx2 = -ky using Eulers Method")
plt.legend()
plt.grid(True)
plt.show()
 
# set k = 10 and h = 0.01
k = 10
h = 0.01
x_values = np.arange(x_start, x_end + h, h)
y_values = np.zeros(len(x_values))
v_values = np.zeros(len(x_values))
 
y_values[0] = y_0
v_values[0] = v_0
 
for i in range(1, len(x_values)):
    x_n = x_values[i - 1]
    y_n = y_values[i - 1]
    v_n = v_values[i - 1]
 
    y_values[i] = y_n + h * v_n
    v_values[i] = v_n + h * (-k * y_n)
 
plt.figure(figsize=(10, 5))
plt.plot(x_values, y_values, label="Position y(x)")
plt.plot(x_values, v_values, label="Velocity v(x)", linestyle="--")
plt.xlabel("x")
plt.ylabel("y and v")
plt.title("Solution of d2y/dx2 = -ky using Eulers Method k=10 h=0.01")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Answers to word questions
#
# it visibly gets unstable around h= .2-.3. the amplitude starts to growing when it should stay the same since it oscilates.
#
# yes it is becoming unstable especially at h= .5
#
# the frequency becomes much faster with k being 10 but since our step size is now much smaller, our solution is still stable and we see this in the second graph.
#
# Euler's method (forward) with large h values is not ideal for oscillatory problems since they become unstable and the amplitude grows over time. this means we need a small h value to combat this which becomes computationally expensive or another method such as runge-kutta.
